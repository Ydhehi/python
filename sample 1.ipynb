# %%
a=int(input("enter a number1:"))
b=int(input("enter a number2:"))
c=a+b
print(c)
# Out:
# enter a number1:4
# enter a number2:1
# 5

# %%
name=input("enter your name:")
age=int(input("enter your age:"))
mark=int(input("enter your mark:"))
print(name)
print(age)
print(mark)
# Out:
# enter your name:vydhehi
# enter your age:21
# enter your mark:75
# vydhehi
# 21
# 75

# %%
age=21
name="Vydhehi"
mark=75.5
passed=True
print(type(age))
print(type(mark))
print(type(name))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=int(input("enter side of square:"))
area=a*a
print(area)
# Out:
# enter side of square:5
# 25

# %%
p=int(input("enter principle amount"))
n=int(input("enter no of years:"))
r=int(input("enter rate of interest:"))
si=(p*n*r)/100
print(si)
# Out:
# enter principle amount10000
# enter no of years:5
# enter rate of interest:5
# 2500.0

# %%
b=int(input("enter base:"))
h=int(input("enter height:"))
a=0.5*b*h
print(a)
# Out:
# enter base:2
# enter height:2
# 2.0

# %%
a=int(input("enter a number:"))
print(a)
print("next number=", a+1)
print("previous number=",a-1)
# Out:
# enter a number:10
# 10
# next number= 11
# previous number= 9

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
print("Sum=",a+b)
print("Difference=",a-b)
print("Product=",a*b)
# Out:
# enter 1st number:5
# enter 2nd number:2
# Sum= 7
# Difference= 3
# Product= 10

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
print("quotient=",a/b)
print("remainder=",a%b)
# Out:
# enter 1st number:4
# enter 2nd number:2
# quotient= 2.0
# remainder= 0

# %%
r=int(input("enter radius of a circle:"))
area=3.14*r*r
print("area is ",area)
# Out:
# enter radius of a circle:5
# area is  78.5

# %%
a=int(input("enter 1st number:"))
b=int(input("enter 2nd number:"))
c=int(input("enter 3rd number:"))
average=(a+b+c)/3
print("average is:",average)
# Out:
# enter 1st number:2
# enter 2nd number:3
# enter 3rd number:4
# average is: 3.0

# %%
c=float(input("enter tempt in celsius:"))
f=(c*9/5)+32
print("tempt in farenheit is ",f)
# Out:
# enter tempt in celsius:25.5
# tempt in farenheit is  77.9
