# %%
day=int(input("enter a number between 1-7:"))
if(day==1):
    print("Monday")
elif(day==2):
    print("Tuesday")
elif(day==3):
    print("Wednesday")
elif(day==4):
    print("Thursday")
elif(day==5):
    print("Friday")
elif(day==6):
    print("Saturday")
elif(day==7):
    print("Sunday")
else:
    print("invalid number")
# Out:
# enter a number between 1-7:6
# Saturday

# %%
month=int(input("enter a number between 1-12:"))
if(month==1):
    print("January")
elif(month==2):
    print("February")
elif(month==3):
    print("March")
elif(month==4):
    print("April")
elif(month==5):
    print("May")
elif(month==6):
    print("june")
elif(month==7):
    print("July")
elif(month==8):
    print("August")
elif(month==9):
    print("September")
elif(month==10):
    print("October")
elif(month==11):
    print("November")
elif(month==12):
    print("December")
else:
    print("invalid number")
# Out:
# enter a number between 1-12:11
# November

# %%
a=int(input("enter a number:"))
if(a%3==0 and a%5==0):
    print("number is divisible by both")
elif(a%3==0):
    print("number is divisible by 3")
elif(a%5==0):
    print("number is divisible by 5")
else:
    print("not divisible by 3, 5, or both")
# Out:
# enter a number:15
# number is divisible by both

# %%
a=int(input("enter a number:"))
if(a%7==0):
    print("divisible by 7")
else:
    print("not divisible by 7")
# Out:
# enter a number:42
# divisible by 7

# %%
ch=input("enter a letter:")
if(ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u' or ch=='A' or ch=='E' or ch=='I' or ch=='O' or ch=='U'):
    print("its a vowel")
else:
    print("not a vowel")
# Out:
# enter a letter:A
# its a vowel

# %%
age=int(input("enter age"))
if(age>=18):
    print("eligible to appy for license")
else:
    print("not eligible")
# Out:
# enter age25
# eligible to appy for license

# %%
str1=input("enter a string:")
str2=input("enter a string:")
if(str1==str2):
    print("both strings are same")
else:
    print("both are different")
# Out:
# enter a string:APPLE
# enter a string:APPLE
# both strings are same

# %%
amt=int(input("enter amount:"))
if(amt>50000):
    print("customer is eligible for discount")
else:
    print("not eligible for discount")
# Out:
# enter amount:100000
# customer is eligible for discount

# %%
n=int(input("enter a number"))
if(n>=10 and n<=100):
    print("the number lies between 10 and 100")
else:
    print("it does not lie between 10 and 100")
# Out:
# enter a number100
# the number lies between 10 and 100

# %%
att=int(input("enter attendence percentage:"))
if(att>=75):
    print("eligible to write the exam")
else:
    print("not eligible to write the exam")
# Out:
# enter attendence percentage:65
# not eligible to write the exam

# %%
ch=input("enter a letter")
if(ch>='A' and ch<='Z'):
    print("UPPERCASE LETTER")
elif(ch>='a' and ch<='z'):
    print("lowercase letter")
else:
    print("not alphabet")
# Out:
# enter a letters
# lowercase letter
